# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X, y= make_regression(n_samples= 4, n_features=1, n_informative=1, n_targets=1, noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg= LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# np.float64(26.15963284313262)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color="red")

# %%
##Now we are going to implement the Gradient Descent

# %%
X,y= make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=20)

# %%
plt.scatter(X,y)

# %%
reg= LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([60.43554243])

# %%
reg.intercept_
# Out:
# np.float64(-0.5831064156056298)

# %%
import pandas as pd

# %%
data= pd.read_csv("placement.csv")

# %%
data.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=data.iloc[:,0]

# %%
x.head()
# Out:
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# Name: cgpa, dtype: float64

# %%
y= data.iloc[:,1]

# %%
y.head()
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %%
plt.scatter(x,y)

# %%
def loss_function(m,b, points):
    total_error=0
    for i in range(len(points)):
        x=points.iloc[i].cgpa
        y= points.iloc[i].package
        total_error+=((y-(m*x+b))**2)
    total_error=total_error/float(len(points))

# %%
def gradient_descent(m_now, b_now, points, L):
    m_gradient=0
    b_gradient=0
    n=len(points)
    for i in range(n):
        x=points.iloc[i].cgpa
        y=points.iloc[i].package
        m_gradient+=-(2/n)*(x)*(y-(x*m_now+b_now))
        b_gradient+=-(2/n)*(y-(x*m_now+b_now))
    m= m_now - (m_gradient*L)
    b= b_now - (b_gradient*L)
    return m,b

# %%
m=0
b=0
l=0.001
epochs=1000
for i in range(epochs):
    m,b= gradient_descent(m,b,data,l)
print(m,b)
x_now=  float(input("enter your cgpa: "))
print(x_now*m+ b)
# Out:
# 0.42983322127870155 0.013604521431122613
# enter your cgpa:  8.26
# 3.564026929193197
